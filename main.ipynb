# %%
from whakaari import TremorData, ForecastModel
import os
import pandas as pd
# Out:
# D:\Projects\miniconda3\envs\whakaari\lib\site-packages\obspy\signal\headers.py:93: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   ], align=True)

# %%
tremor_data = TremorData(
    station='OJN',
    data_dir=os.getcwd(),
    eruptive_file=r'D:\Projects\whakaari\input\OJN_eruptive_periods.txt',
    n_jobs=1,
    verbose=True,
)
# Out:
# Version: 0.0.1
# Station: OJN
# Parent: None
# Data Dir: D:\Projects\whakaari
# Tremor Data file: D:\Projects\whakaari\output\OJN_tremor_data.csv
# Tremor Data exists: True
# Eruption file: D:\Projects\whakaari\input\OJN_eruptive_periods.txt
# Number of jobs: 1
# Cols: ['vlar', 'lrar', 'rmar', 'dsar', 'vlarF', 'lrarF', 'rmarF', 'dsarF', 'vlf', 'lf', 'rsam', 'mf', 'hf', 'vlfF', 'lfF', 'rsamF', 'mfF', 'hfF']
# 📖 Reading from CSV file: D:\Projects\whakaari\output\OJN_tremor_data.csv
# ⚠️ Data not found in tremor file :: D:\Projects\whakaari\output\OJN_tremor_data.csv

# %%
tremor_data.stations = {
    "OJN": {
        'client_name': "GEONET",
        'nrt_name': 'https://service.geonet.org.nz',
        'channel': 'EHN',
        'network': 'VG',
        'location': '00',
    },
}

# %%
tremor_data.update(
    datetime_start='2025-01-01 00:00:00',
    datetime_end='2025-05-28 23:59:59',
    sds_dir=r'D:\Data\OJN')
# Out:
# ============================================================
# Station OJN: Downloading data in serial
# ============================================================
# ⌚ Progress :: 1/147
# ✅ Temp file exists :: D:\Projects\whakaari\_tmp\OJN\_tmp_fl_00000.csv
# ============================================================
# ⌚ Progress :: 2/147
# ✅ Temp file exists :: D:\Projects\whakaari\_tmp\OJN\_tmp_fl_00001.csv
# ============================================================
# ⌚ Progress :: 3/147
# ✅ Temp file exists :: D:\Projects\whakaari\_tmp\OJN\_tmp_fl_00002.csv
# ============================================================
# ⌚ Progress :: 4/147
# 📶 Pre-processing data, apply filter...
# Start time : 2025-01-04T00:00:00.000000Z
# 🧮 Computing RSAM ... Done
# 🧮 Computing DSAR ... Done
# ============================================================
# ⌚ Progress :: 5/147
# 📶 Pre-processing data, apply filter...
# Start time : 2025-01-05T00:00:00.000000Z
# 🧮 Computing RSAM ... Done
# 🧮 Computing DSAR ... Done
# ============================================================
# ⌚ Progress :: 6/147
# 📶 Pre-processing data, apply filter...
# Start time : 2025-01-06T00:00:00.000000Z
# 🧮 Computing RSAM ... Done
# 🧮 Computing DSAR ... Done
# ============================================================
# ⌚ Progress :: 7/147
# 📶 Pre-processing data, apply filter...
# Start time : 2025-01-07T00:00:00.000000Z
# 🧮 Computing RSAM ... Done
# 🧮 Computing DSAR ... Done
# ============================================================
# ⌚ Progress :: 8/147
# 📶 Pre-processing data, apply filter...
# Start time : 2025-01-08T00:00:00.000000Z
# 🧮 Computing RSAM ... Done
# 🧮 Computing DSAR ... Done
# ============================================================
# ⌚ Progress :: 9/147
# 📶 Pre-processing data, apply filter...
# Start time : 2025-01-09T00:00:00.000000Z
# 🧮 Computing RSAM ... Done
# 🧮 Computing DSAR ... Done
# ============================================================
# ⌚ Progress :: 10/147
# 📶 Pre-processing data, apply filter...
# Start time : 2025-01-10T00:00:00.000000Z
# 🧮 Computing RSAM ... Done
# 🧮 Computing DSAR ... Done
# ============================================================
# ⌚ Progress :: 11/147
# 📶 Pre-processing data, apply filter...
# Start time : 2025-01-11T00:00:00.000000Z
# 🧮 Computing RSAM ... Done
# 🧮 Computing DSAR ... Done
# ============================================================
# ⌚ Progress :: 12/147
# 📶 Pre-processing data, apply filter...
# Start time : 2025-01-12T00:00:00.000000Z
# 🧮 Computing RSAM ... Done
# 🧮 Computing DSAR ... Done
# ============================================================
# ⌚ Progress :: 13/147
# 📶 Pre-processing data, apply filter...
# Start time : 2025-01-13T00:00:00.000000Z
# 🧮 Computing RSAM ... Done
# 🧮 Computing DSAR ... Done
# ============================================================
# ⌚ Progress :: 14/147
# 📶 Pre-processing data, apply filter...
# Start time : 2025-01-14T00:00:00.000000Z
# 🧮 Computing RSAM ... Done
# 🧮 Computing DSAR ... Done
# ============================================================
# ⌚ Progress :: 15/147
# 📶 Pre-processing data, apply filter...
# Start time : 2025-01-15T00:00:00.000000Z
# 🧮 Computing RSAM ... Done
# 🧮 Computing DSAR ... Done
# ============================================================
# ⌚ Progress :: 16/147
# 📶 Pre-processing data, apply filter...
# Start time : 2025-01-16T00:00:00.000000Z
# 🧮 Computing RSAM ... Done
# 🧮 Computing DSAR ... Done
# ============================================================
# ⌚ Progress :: 17/147
# 📶 Pre-processing data, apply filter...
# Start time : 2025-01-17T00:00:00.000000Z
# 🧮 Computing RSAM ... Done
# 🧮 Computing DSAR ... Done
# ============================================================
# ⌚ Progress :: 18/147
# 📶 Pre-processing data, apply filter...
# Start time : 2025-01-18T00:00:00.000000Z
# 🧮 Computing RSAM ... Done
# 🧮 Computing DSAR ... Done
# ============================================================
# ⌚ Progress :: 19/147
# 📶 Pre-processing data, apply filter...
# Start time : 2025-01-19T00:00:00.000000Z
# 🧮 Computing RSAM ... Done
# 🧮 Computing DSAR ... Done
# ============================================================
# ⌚ Progress :: 20/147
# 📶 Pre-processing data, apply filter...
# Start time : 2025-01-20T00:00:00.000000Z
# 🧮 Computing RSAM ... Done
# 🧮 Computing DSAR ... Done
# ============================================================
# ⌚ Progress :: 21/147
# 📶 Pre-processing data, apply filter...
# Start time : 2025-01-21T00:00:00.000000Z
# 🧮 Computing RSAM ... Done
# 🧮 Computing DSAR ... Done
# ============================================================
# ⌚ Progress :: 22/147
# 📶 Pre-processing data, apply filter...
# Start time : 2025-01-22T00:00:00.000000Z
# D:\Projects\miniconda3\envs\whakaari\lib\site-packages\whakaari\utils.py:140: RuntimeWarning: divide by zero encountered in double_scalars
#   z_score = (data[max_idx] - mean) / std
# 🧮 Computing RSAM ... Done
# 🧮 Computing DSAR ... Done
# ============================================================
# ⌚ Progress :: 23/147
# 📶 Pre-processing data, apply filter...
# Start time : 2025-01-23T00:00:00.000000Z
# 🧮 Computing RSAM ... Done
# 🧮 Computing DSAR ... Done
# ============================================================
# ⌚ Progress :: 24/147
# 📶 Pre-processing data, apply filter...
# Start time : 2025-01-24T00:00:00.000000Z
# 🧮 Computing RSAM ... Done
# 🧮 Computing DSAR ... Done
# ============================================================
# ⌚ Progress :: 25/147
# 📶 Pre-processing data, apply filter...
# Start time : 2025-01-25T00:00:00.000000Z
# 🧮 Computing RSAM ... Done
# 🧮 Computing DSAR ... Done
# ============================================================
# ⌚ Progress :: 26/147
# 📶 Pre-processing data, apply filter...
# Start time : 2025-01-26T00:00:00.000000Z
# 🧮 Computing RSAM ... Done
# 🧮 Computing DSAR ... Done
# ============================================================
# ⌚ Progress :: 27/147
# 📶 Pre-processing data, apply filter...
# Start time : 2025-01-27T00:00:00.000000Z
# 🧮 Computing RSAM ... Done
# 🧮 Computing DSAR ... Done
# ============================================================
# ⌚ Progress :: 28/147
# 📶 Pre-processing data, apply filter...
# Start time : 2025-01-28T00:00:00.000000Z
# 🧮 Computing RSAM ... Done
# 🧮 Computing DSAR ... Done
# ============================================================
# ⌚ Progress :: 29/147
# 📶 Pre-processing data, apply filter...
# Start time : 2025-01-29T00:00:00.000000Z
# 🧮 Computing RSAM ... Done
# 🧮 Computing DSAR ... Done
# ============================================================
# ⌚ Progress :: 30/147
# 📶 Pre-processing data, apply filter...
# Start time : 2025-01-30T00:00:00.000000Z
# 🧮 Computing RSAM ... Done
# 🧮 Computing DSAR ... Done
# ============================================================
# ⌚ Progress :: 31/147
# 📶 Pre-processing data, apply filter...
# Start time : 2025-01-31T00:00:00.000000Z
# 🧮 Computing RSAM ... Done
# 🧮 Computing DSAR ... Done
# ============================================================
# ⌚ Progress :: 32/147
# 📶 Pre-processing data, apply filter...
# Start time : 2025-02-01T00:00:00.000000Z
# 🧮 Computing RSAM ... Done
# 🧮 Computing DSAR ... Done
# ============================================================
# ⌚ Progress :: 33/147
# 📶 Pre-processing data, apply filter...
# Start time : 2025-02-02T00:00:00.000000Z
# 🧮 Computing RSAM ... Done
# 🧮 Computing DSAR ... Done
# ============================================================
# ⌚ Progress :: 34/147
# 📶 Pre-processing data, apply filter...
# Start time : 2025-02-03T00:00:00.000000Z
# 🧮 Computing RSAM ... Done
# 🧮 Computing DSAR ... Done
# ============================================================
# ⌚ Progress :: 35/147
# 📶 Pre-processing data, apply filter...
# Start time : 2025-02-04T00:00:00.000000Z
# 🧮 Computing RSAM ... Done
# 🧮 Computing DSAR ... Done
# ============================================================
# ⌚ Progress :: 36/147
# 📶 Pre-processing data, apply filter...
# Start time : 2025-02-05T00:00:00.000000Z
# 🧮 Computing RSAM ... Done
# 🧮 Computing DSAR ... Done
# ============================================================
# ⌚ Progress :: 37/147
# 📶 Pre-processing data, apply filter...
# Start time : 2025-02-06T00:00:00.000000Z
# 🧮 Computing RSAM ... Done
# 🧮 Computing DSAR ... Done
# ============================================================
# ⌚ Progress :: 38/147
# 📶 Pre-processing data, apply filter...
# Start time : 2025-02-07T00:00:00.000000Z
# 🧮 Computing RSAM ... Done
# 🧮 Computing DSAR ... Done
# ============================================================
# ⌚ Progress :: 39/147
# 📶 Pre-processing data, apply filter...
# Start time : 2025-02-08T00:00:00.000000Z
# 🧮 Computing RSAM ... Done
# 🧮 Computing DSAR ... Done
# ============================================================
# ⌚ Progress :: 40/147
# 📶 Pre-processing data, apply filter...
# Start time : 2025-02-09T00:00:00.000000Z
# 🧮 Computing RSAM ... Done
# 🧮 Computing DSAR ... Done
# ============================================================
# ⌚ Progress :: 41/147
# 📶 Pre-processing data, apply filter...
# Start time : 2025-02-10T00:00:00.000000Z
# 🧮 Computing RSAM ... Done
# 🧮 Computing DSAR ... Done
# ============================================================
# ⌚ Progress :: 42/147
# 📶 Pre-processing data, apply filter...
# Start time : 2025-02-11T00:00:00.000000Z
# 🧮 Computing RSAM ... Done
# 🧮 Computing DSAR ... Done
# ============================================================
# ⌚ Progress :: 43/147
# 📶 Pre-processing data, apply filter...
# Start time : 2025-02-12T00:00:00.000000Z
# 🧮 Computing RSAM ... Done
# 🧮 Computing DSAR ... Done
# ============================================================
# ⌚ Progress :: 44/147
# 📶 Pre-processing data, apply filter...
# Start time : 2025-02-13T00:00:00.000000Z
# 🧮 Computing RSAM ... Done
# 🧮 Computing DSAR ... Done
# ============================================================
# ⌚ Progress :: 45/147
# 📶 Pre-processing data, apply filter...
# Start time : 2025-02-14T00:00:00.000000Z
# 🧮 Computing RSAM ... Done
# 🧮 Computing DSAR ... Done
# ============================================================
# ⌚ Progress :: 46/147
# 📶 Pre-processing data, apply filter...
# Start time : 2025-02-15T00:00:00.000000Z
# 🧮 Computing RSAM ... Done
# 🧮 Computing DSAR ... Done
# ============================================================
# ⌚ Progress :: 47/147
# 📶 Pre-processing data, apply filter...
# Start time : 2025-02-16T00:00:00.000000Z
# 🧮 Computing RSAM ... Done
# 🧮 Computing DSAR ... Done
# ============================================================
# ⌚ Progress :: 48/147
# 📶 Pre-processing data, apply filter...
# Start time : 2025-02-17T00:00:00.000000Z
# 🧮 Computing RSAM ... Done
# 🧮 Computing DSAR ... Done
# ============================================================
# ⌚ Progress :: 49/147
# 📶 Pre-processing data, apply filter...
# Start time : 2025-02-18T00:00:00.000000Z
# 🧮 Computing RSAM ... Done
# 🧮 Computing DSAR ... Done
# ============================================================
# ⌚ Progress :: 50/147
# 📶 Pre-processing data, apply filter...
# Start time : 2025-02-19T00:00:00.000000Z
# 🧮 Computing RSAM ... Done
# 🧮 Computing DSAR ... Done
# ============================================================
# ⌚ Progress :: 51/147
# 📶 Pre-processing data, apply filter...
# Start time : 2025-02-20T00:00:00.000000Z
# 🧮 Computing RSAM ... Done
# 🧮 Computing DSAR ... Done
# ============================================================
# ⌚ Progress :: 52/147
# 📶 Pre-processing data, apply filter...
# Start time : 2025-02-21T00:00:00.000000Z
# 🧮 Computing RSAM ... Done
# 🧮 Computing DSAR ... Done
# ============================================================
# ⌚ Progress :: 53/147
# 📶 Pre-processing data, apply filter...
# Start time : 2025-02-22T00:00:00.000000Z
# 🧮 Computing RSAM ... Done
# 🧮 Computing DSAR ... Done
# ============================================================
# ⌚ Progress :: 54/147
# 📶 Pre-processing data, apply filter...
# Start time : 2025-02-23T00:00:00.000000Z
# 🧮 Computing RSAM ... Done
# 🧮 Computing DSAR ... Done
# ============================================================
# ⌚ Progress :: 55/147
# 📶 Pre-processing data, apply filter...
# Start time : 2025-02-24T00:00:00.000000Z
# 🧮 Computing RSAM ... Done
# 🧮 Computing DSAR ... Done
# ============================================================
# ⌚ Progress :: 56/147
# 📶 Pre-processing data, apply filter...
# Start time : 2025-02-25T00:00:00.000000Z
# 🧮 Computing RSAM ... Done
# 🧮 Computing DSAR ... Done
# ============================================================
# ⌚ Progress :: 57/147
# 📶 Pre-processing data, apply filter...
# Start time : 2025-02-26T00:00:00.000000Z
# 🧮 Computing RSAM ... Done
# 🧮 Computing DSAR ... Done
# ============================================================
# ⌚ Progress :: 58/147
# 📶 Pre-processing data, apply filter...
# Start time : 2025-02-27T00:00:00.000000Z
# 🧮 Computing RSAM ... Done
# 🧮 Computing DSAR ... Done
# ============================================================
# ⌚ Progress :: 59/147
# 📶 Pre-processing data, apply filter...
# Start time : 2025-02-28T00:00:00.000000Z
# 🧮 Computing RSAM ... Done
# 🧮 Computing DSAR ... Done
# ============================================================
# ⌚ Progress :: 60/147
# 📶 Pre-processing data, apply filter...
# Start time : 2025-03-01T00:00:00.000000Z
# 🧮 Computing RSAM ... Done
# 🧮 Computing DSAR ... Done
# ============================================================
# ⌚ Progress :: 61/147
# 📶 Pre-processing data, apply filter...
# Start time : 2025-03-02T00:00:00.000000Z
# 🧮 Computing RSAM ... Done
# 🧮 Computing DSAR ... Done
# ============================================================
# ⌚ Progress :: 62/147
# 📶 Pre-processing data, apply filter...
# Start time : 2025-03-03T00:00:00.000000Z
# 🧮 Computing RSAM ... Done
# 🧮 Computing DSAR ... Done
# ============================================================
# ⌚ Progress :: 63/147
# 📶 Pre-processing data, apply filter...
# Start time : 2025-03-04T00:00:00.000000Z
# 🧮 Computing RSAM ... Done
# 🧮 Computing DSAR ... Done
# ============================================================
# ⌚ Progress :: 64/147
# 📶 Pre-processing data, apply filter...
# Start time : 2025-03-05T00:00:00.000000Z
# 🧮 Computing RSAM ... Done
# 🧮 Computing DSAR ... Done
# ============================================================
# ⌚ Progress :: 65/147
# 📶 Pre-processing data, apply filter...
# Start time : 2025-03-06T00:00:00.000000Z
# 🧮 Computing RSAM ... Done
# 🧮 Computing DSAR ... Done
# ============================================================
# ⌚ Progress :: 66/147
# 📶 Pre-processing data, apply filter...
# Start time : 2025-03-07T00:00:00.000000Z
# 🧮 Computing RSAM ... Done
# 🧮 Computing DSAR ... Done
# ============================================================
# ⌚ Progress :: 67/147
# 📶 Pre-processing data, apply filter...
# Start time : 2025-03-08T00:00:00.000000Z
# 🧮 Computing RSAM ... Done
# 🧮 Computing DSAR ... Done
# ============================================================
# ⌚ Progress ::