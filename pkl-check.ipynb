# %%
from whakaari.utils import load_dataframe
# Out:
# C:\Users\Martanto\miniconda3\envs\whakaari_env\lib\site-packages\obspy\signal\headers.py:93: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   ], align=True)

# %%
pkl_model = r"D:\Project\whakaari\output\features\fm_2.00w_dsar_OJN_2025.pkl"

# %%
df = load_dataframe(pkl_model)

# %%
df
# Out:
#                      dsar__abs_energy  dsar__absolute_sum_of_changes  \
# time
# 2025-01-03 00:00:00        881.515167                      57.189924
# 2025-01-03 12:00:00        859.924311                      58.713719
# 2025-01-04 00:00:00        954.738413                      57.599468
# 2025-01-04 12:00:00        972.299619                      53.194733
# 2025-01-05 00:00:00        958.238205                      54.767432
# ...                               ...                            ...
# 2025-06-18 23:20:00        707.301549                      82.493058
# 2025-06-18 23:30:00        706.233647                      81.885928
# 2025-06-18 23:40:00        702.342735                      81.712097
# 2025-06-18 23:50:00        698.901815                      81.877664
# 2025-06-19 00:00:00        695.148821                      81.546442
#
#                      dsar__agg_autocorrelation__f_agg_"mean"__maxlag_40  \
# time
# ...
